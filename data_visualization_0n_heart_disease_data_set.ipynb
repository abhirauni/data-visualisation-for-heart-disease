# %%
import pandas as pd
import numpy as np
import seaborn as sng
import matplotlib.pyplot as plt
import sklearn as skl

# %%
### EDA==EXPLORATORY DATA ANALYSIS

# %%
df=pd.read_csv("Heart_Disease_Data.csv")
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG
# 0     40   M           ATA        140          289          0     Normal  \
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# # #(1)analyzing Age Column (dist plot)

# %%
df["Age"].nunique()
# Out:
# 50

# %%
df.groupby("Age").size().plot(kind="bar",figsize=(15,8))
# Out:
# <Axes: xlabel='Age'>

# %%
sng.displot(df["Age"])

# %%
sng.displot(df["Age"],kde=True)

# %%
sng.distplot(df["Age"])
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\2671435842.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Age"])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sng.distplot(df["Age"],kde=True,hist=True)
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\2877322955.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Age"],kde=True,hist=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sng.distplot(df["Age"],kde=False)
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\1623464058.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Age"],kde=False)
# <Axes: xlabel='Age'>

# %%
sng.distplot(df["Age"],kde=True,rug=True,hist=True)
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\1804470897.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Age"],kde=True,rug=True,hist=True)
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sng.distplot(df["Age"],kde=True,bins=15,color="red")
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\1074864780.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Age"],kde=True,bins=15,color="red")
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # #(2)Pie Charts

# %%
df.head(2)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
# 1   49   F           NAP        160          180          0     Normal    156
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1

# %% [markdown]
# #### (A)Distribution plot of numeric column

# %%
sng.distplot(df["RestingBP"],kde=True,rug=False,color="red")
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\1739135851.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["RestingBP"],kde=True,rug=False,color="red")
# <Axes: xlabel='RestingBP', ylabel='Density'>

# %%
sng.displot(df["RestingBP"],kde=True,color="blue")

# %%
sng.displot(df["Cholesterol"],kde=True,color="blue")

# %%
sng.distplot(df["Cholesterol"],kde=True,color="blue")
# Out:
# C:\Users\ABHISHEK RAUNIYAR\AppData\Local\Temp\ipykernel_29028\2281865324.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sng.distplot(df["Cholesterol"],kde=True,color="blue")
# <Axes: xlabel='Cholesterol', ylabel='Density'>

# %%
sng.displot(df["FastingBS"],kde=True,color="blue")

# %%
sng.displot(df["Oldpeak"],kde=True,color="blue")

# %%
sng.displot(df["MaxHR"],kde=True,color="blue")

# %% [markdown]
# ##### (B)Distribution plot for categorical column

# %%
df.groupby("Sex").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ChestPainType").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("RestingECG").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ExerciseAngina").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("ST_Slope").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %%
df.groupby("HeartDisease").size().plot(kind="pie",autopct="%.2f%%")
# Out:
# <Axes: >

# %% [markdown]
# # #(3)Violin plot

# %%
sng.violinplot(x=df["HeartDisease"],y=df["Sex"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Sex'>

# %%
sng.violinplot(x=df["Sex"],y=df["HeartDisease"])
# Out:
# <Axes: xlabel='Sex', ylabel='HeartDisease'>

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %%
sng.violinplot(y=df["ChestPainType"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ChestPainType'>

# %%
sng.violinplot(x=df["RestingECG"],y=df["HeartDisease"])
# Out:
# <Axes: xlabel='RestingECG', ylabel='HeartDisease'>

# %%
sng.violinplot(x=df["ExerciseAngina"],y=df["HeartDisease"])
# Out:
# <Axes: xlabel='ExerciseAngina', ylabel='HeartDisease'>

# %%
sng.violinplot(y=df["ST_Slope"],x=df["HeartDisease"])
# Out:
# <Axes: xlabel='HeartDisease', ylabel='ST_Slope'>

# %% [markdown]
# # #(4)correlation(Heat Map)

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df.corr()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sng.heatmap(df.corr())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 sng.heatmap(df.corr())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10059, in DataFrame.corr(self, method, min_periods, numeric_only)
#   10057 cols = data.columns
#   10058 idx = cols.copy()
# > 10059 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   10061 if method == "pearson":
#   10062     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:1838, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1836 if dtype is not None:
#    1837     dtype = np.dtype(dtype)
# -> 1838 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1839 if result.dtype is not dtype:
#    1840     result = np.array(result, dtype=dtype, copy=False)
#
# ...

# %%
sng.heatmap(df.corr(x=df["Age"],y=df["Sex"]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 sng.heatmap(df.corr(x=df["Age"],y=df["Sex"]))
#
# TypeError: DataFrame.corr() got an unexpected keyword argument 'x'

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %% [markdown]
# # #(5)correlation (Joint Plot)

# %%
sng.jointplot(x="Age",y="MaxHR",data=df)

# %%
sng.jointplot(x="Age",y="MaxHR",data=df,kind="reg")

# %%
sng.jointplot(x="Age",y="Age",data=df,kind="reg")

# %%
sng.jointplot(x="HeartDisease",y="Oldpeak",data=df,kind="reg")

# %%
sng.jointplot(x="HeartDisease",y="Oldpeak",data=df,kind="hex")

# %%
sng.jointplot(x="HeartDisease",y="Age",data=df)

# %%
sng.jointplot(x="HeartDisease",y="Age",data=df,kind="reg")

# %%
sng.jointplot(x="Cholesterol",y="FastingBS",data=df,kind="reg")

# %%
df.head(1)
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR
# 0   40   M           ATA        140          289          0     Normal    172  \
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0

# %%
sng.jointplot(x="Cholesterol",y="FastingBS",data=df,kind="resid")

# %% [markdown]
# # #(6)Correlation (Pair Plot)

# %%
sng.pairplot(df)

# %%
sng.jointplot(x="Cholesterol",y="MaxHR",data=df,kind="reg")
